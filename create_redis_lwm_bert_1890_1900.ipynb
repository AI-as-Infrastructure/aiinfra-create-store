# %%
# Import necessary libraries
import os, re, torch, hashlib, uuid, json, redis
import numpy as np
from transformers import AutoTokenizer, AutoModel
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter  # Import other text splitters as needed
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores.redis import Redis
from langchain.schema import Document  # Import Document abstraction
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Directory paths and metadata
corpora = {
    "/home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt": "1901-au",
    "/home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/nz/hofreps/txt": "1901-nz",
    "/home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt": "1901-uk"
}

# Access the EMBEDDING_MODEL environment variable
EMBEDDING_MODEL = os.getenv('EMBEDDING_MODEL')

# Access the REDIS_URL environment variable
REDIS_URL = os.getenv('REDIS_URL')

# Access the INDEX_NAME environment variable
INDEX_NAME = os.getenv('INDEX_NAME')

# Access the TEXT_SPLITTER_TYPE, CHUNK_SIZE, and CHUNK_OVERLAP environment variables
TEXT_SPLITTER_TYPE = os.getenv('TEXT_SPLITTER_TYPE', 'RecursiveCharacterTextSplitter')
CHUNK_SIZE = int(os.getenv('CHUNK_SIZE', 500))
CHUNK_OVERLAP = int(os.getenv('CHUNK_OVERLAP', 75))

# Function to initialize the text splitter based on the type
def get_text_splitter(splitter_type, chunk_size, chunk_overlap):
    if splitter_type == 'RecursiveCharacterTextSplitter':
        return RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    elif splitter_type == 'CharacterTextSplitter':
        return CharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    else:
        raise ValueError(f"Unsupported text splitter type: {splitter_type}")

# Connect to Redis, either locally (if installed) or Redis Cloud (details in .env)
redis_client = redis.Redis.from_url(REDIS_URL)

# Load a tokenizer and model for embedding
tokenizer = AutoTokenizer.from_pretrained(EMBEDDING_MODEL)
model = AutoModel.from_pretrained(EMBEDDING_MODEL)

# Function to compute embeddings using Langchain
def compute_embedding(text):
    try:
        inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
        return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
    except Exception as e:
        print(f"Error computing embedding for text: {text[:50]}... - {str(e)}")
        return None

# Extract date from filename
def extract_date_from_filename(filename):
    print(f"Extracting date from filename: {filename}")  # Debug print
    match = re.search(r'(\w+, \d{1,2}(?:st|nd|rd|th)? \w+, \d{4})', filename)
    if match:
        date = match.group(0)
        print(f"Extracted date: {date}")  # Debug print
        return date
    print("No date found, returning 'Unknown Date'")  # Debug print
    return "Unknown Date"

# Extract URL from text
def extract_url(text):
    matches = re.finditer(r'<url>(https?://[^\s]+)</url>', text)
    return [(match.start(), match.group(1)) for match in matches]

# Extract page number from text
def extract_page_number(text):
    matches = re.finditer(r'<page>(\d+)</page>', text)
    return [(match.start(), match.group(1)) for match in matches]

# Modify the generate_unique_key function to include corpus metadata
def generate_unique_key(base_key, chunk_idx, corpus_metadata):
    return f"{base_key}:{corpus_metadata}:{chunk_idx}"

# Update the process_corpus function to pass the corpus metadata
def process_corpus(directory, metadata):
    # Load documents using Langchain's DirectoryLoader
    loader = DirectoryLoader(directory, glob="*.txt")
    documents = loader.load()
    
    # Initialize the text splitter
    text_splitter = get_text_splitter(TEXT_SPLITTER_TYPE, CHUNK_SIZE, CHUNK_OVERLAP)
    
    chunk_counter = 0
    texts = []
    metadatas = []
    embeddings = []
    
    for doc in documents:
        # Extract metadata from the entire document content
        date_info = extract_date_from_filename(doc.metadata['source'])
        url_info = extract_url(doc.page_content)
        page_info = extract_page_number(doc.page_content)
        
        # Log the extracted metadata
        print(f"Extracted URL: {url_info} from document: {doc.metadata['source']}")
        print(f"Extracted Page Numbers: {page_info} from document: {doc.metadata['source']}")
        
        # Check if there is a URL at the top of the document
        top_url = url_info[0][1] if url_info else None
        
        # Check if there are any page tags
        if not page_info:
            # Process the entire document as a single section
            current_url = top_url
            clean_section = re.sub(r'<url>https?://[^\s]+</url>', '', doc.page_content)
            chunked_texts = text_splitter.split_text(clean_section)
            for chunk_idx, chunk in enumerate(chunked_texts):
                embedding = compute_embedding(chunk)
                if embedding is not None:
                    # Generate a unique key for each chunk
                    redis_key = generate_unique_key(f"doc:{INDEX_NAME}", chunk_counter, metadata)
                    chunk_counter += 1
                    
                    # Create metadata in the required format
                    metadata_dict = {
                        "source": doc.metadata['source'],
                        "date": date_info,
                        "url": current_url,
                        "page": None,
                        "loc": json.dumps({
                            "lines": {
                                "from": chunk_idx * (CHUNK_SIZE - CHUNK_OVERLAP) + 1,
                                "to": (chunk_idx + 1) * CHUNK_SIZE
                            }
                        }),
                        "corpus": metadata 
                    }
                    
                    # Append to lists for batch processing
                    texts.append(chunk)
                    metadatas.append(metadata_dict)
                    embeddings.append(embedding.tolist())
        else:
            # Split the document into sections based on <page> tags
            sections = re.split(r'(<page>\d+</page>)', doc.page_content)
            
            current_page = None
            current_url = None
            for section in sections:
                if section.startswith('<page>'):
                    current_page = int(re.search(r'<page>(\d+)</page>', section).group(1))
                    # If there is no URL under page tags, use the top URL
                    if not any(url for pos, url in url_info if pos > section.find('<page>')):
                        current_url = top_url
                else:
                    # Update the current URL if the section contains a new URL tag
                    for pos, url in url_info:
                        if section.find(url) != -1:
                            current_url = url
                            break
                    
                    if current_page is not None:
                        # Remove URL tags from the section
                        clean_section = re.sub(r'<url>https?://[^\s]+</url>', '', section)
                        
                        chunked_texts = text_splitter.split_text(clean_section)
                        for chunk_idx, chunk in enumerate(chunked_texts):
                            embedding = compute_embedding(chunk)
                            if embedding is not None:
                                # Generate a unique key for each chunk
                                redis_key = generate_unique_key(f"doc:{INDEX_NAME}", chunk_counter, metadata)
                                chunk_counter += 1
                                
                                # Create metadata in the required format
                                metadata_dict = {
                                    "source": doc.metadata['source'],
                                    "date": date_info,
                                    "url": current_url,
                                    "page": current_page,
                                    "loc": json.dumps({
                                        "lines": {
                                            "from": chunk_idx * (CHUNK_SIZE - CHUNK_OVERLAP) + 1,
                                            "to": (chunk_idx + 1) * CHUNK_SIZE
                                        }
                                    }),
                                    "corpus": metadata 
                                }
                                
                                # Append to lists for batch processing
                                texts.append(chunk)
                                metadatas.append(metadata_dict)
                                embeddings.append(embedding.tolist())

    # Add texts to the vector store to create the index
    vector_store.add_texts(texts, metadatas=metadatas, embeddings=embeddings)

    print(f"Finished processing corpus: {metadata}")

# Initialize HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL)

# Initialize Redis vector store
vector_store = Redis(
    redis_url=REDIS_URL,
    embedding=embeddings,
    index_name=INDEX_NAME,
)

# Process each corpus
for directory, metadata in corpora.items():
    process_corpus(directory, metadata)
# Out:
# /home/jamessmithies/Dropbox/Technical/projects/aiinfra/aiinfra-create-store/.venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# No sentence-transformers model found with name Livingwithmachines/bert_1890_1900. Creating a new one with mean pooling.
# /home/jamessmithies/Dropbox/Technical/projects/aiinfra/aiinfra-create-store/.venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/8-Thursday, 11th July, 1901.txt
# Extracted date: Thursday, 11th July, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=304'), (3817, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=305'), (9949, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=306'), (15034, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=307'), (20360, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=308'), (26508, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=309'), (32400, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=310'), (38655, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=311'), (44873, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=312'), (51077, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=313'), (57227, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=314'), (63578, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=315'), (69968, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=316'), (76498, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=317'), (82963, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=318'), (89044, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=319'), (95202, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=320'), (101573, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=321'), (107946, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=322'), (114467, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=323'), (120877, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=324'), (127172, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=325'), (133433, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=326'), (139785, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=327'), (146130, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=328'), (152259, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=329'), (158602, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=330'), (164907, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=331'), (170439, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=332'), (176729, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=333'), (183065, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=334'), (189347, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=335'), (195587, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=336'), (201905, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=337'), (208291, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=338'), (214443, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=339'), (220802, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=340'), (226949, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=341'), (233089, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=342'), (239222, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=343'), (245459, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=344'), (251710, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=345'), (258103, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=346'), (264422, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=347'), (270610, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=348'), (276950, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=349'), (283146, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=350'), (289560, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=351'), (295831, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=352'), (302133, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=353')] from document: /home/jamessmithies/Dropbox/Technical/pro ...
# Extracted Page Numbers: [(0, '276'), (3799, '277'), (9931, '278'), (15016, '279'), (20342, '280'), (26490, '281'), (32382, '282'), (38637, '283'), (44855, '284'), (51059, '285'), (57209, '286'), (63560, '287'), (69950, '288'), (76480, '289'), (82945, '290'), (89026, '291'), (95184, '292'), (101555, '293'), (107928, '294'), (114449, '295'), (120859, '296'), (127154, '297'), (133415, '298'), (139767, '299'), (146112, '300'), (152241, '301'), (158584, '302'), (164889, '303'), (170421, '304'), (176711, '305'), (183047, '306'), (189329, '307'), (195569, '308'), (201887, '309'), (208273, '310'), (214425, '311'), (220784, '312'), (226931, '313'), (233071, '314'), (239204, '315'), (245441, '316'), (251692, '317'), (258085, '318'), (264404, '319'), (270592, '320'), (276932, '321'), (283128, '322'), (289542, '323'), (295813, '324'), (302115, '325')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/8-Thursday, 11th July, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/6-Wednesday, 11th September, 1901.txt
# Extracted date: Wednesday, 11th September, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=418'), (1933, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=419'), (8076, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=420'), (14182, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=421'), (20369, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=422'), (26627, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=423'), (32883, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=424'), (39099, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=425'), (45397, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=426'), (51403, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=427'), (56942, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=428'), (62984, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=429'), (69250, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=430'), (75345, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=431'), (81451, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=432'), (87689, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=433'), (93660, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=434'), (99727, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=435'), (105593, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=436'), (111849, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=437'), (117855, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=438'), (123825, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=439'), (129855, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=440'), (135734, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=441'), (141939, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=442'), (148245, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=443'), (154437, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=444'), (160254, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=445'), (166310, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=446'), (172186, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=447'), (178327, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=448'), (184263, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=449'), (190489, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=450'), (196689, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=451'), (202981, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=452'), (209218, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=453'), (215206, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=454'), (221182, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=455'), (227180, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=456'), (233169, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=457'), (239051, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=458'), (245096, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=459'), (251280, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=460'), (257297, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=461'), (263253, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=462'), (269190, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=463'), (275053, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=464'), (281180, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=465'), (287219, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=466'), (293251, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=467'), (298160, 'https://babel.hathitrust.org/cgi/pt?id=uc1.3210 ...
# Extracted Page Numbers: [(0, '398'), (1915, '399'), (8058, '400'), (14164, '401'), (20351, '402'), (26609, '403'), (32865, '404'), (39081, '405'), (45379, '406'), (51385, '407'), (56924, '408'), (62966, '409'), (69232, '410'), (75327, '411'), (81433, '412'), (87671, '413'), (93642, '414'), (99709, '415'), (105575, '416'), (111831, '417'), (117837, '418'), (123807, '419'), (129837, '420'), (135716, '421'), (141921, '422'), (148227, '423'), (154419, '424'), (160236, '425'), (166292, '426'), (172168, '427'), (178309, '428'), (184245, '429'), (190471, '430'), (196671, '431'), (202963, '432'), (209200, '433'), (215188, '434'), (221164, '435'), (227162, '436'), (233151, '437'), (239033, '438'), (245078, '439'), (251262, '440'), (257279, '441'), (263235, '442'), (269172, '443'), (275035, '444'), (281162, '445'), (287201, '446'), (293233, '447'), (298142, '448'), (303798, '449'), (310010, '450'), (316087, '451'), (322247, '452'), (328415, '453'), (333948, '454')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/6-Wednesday, 11th September, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/2-Friday, 27th September, 1901.txt
# Extracted date: Friday, 27th September, 1901
# Extracted URL: [(17, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=79'), (3883, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=80'), (9518, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=81'), (15557, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=82'), (21578, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=83'), (27495, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=84'), (33496, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=85'), (39475, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=86'), (45292, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=87'), (51269, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=88'), (57060, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=89'), (63069, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=90'), (69005, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=91'), (75141, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=92'), (81212, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=93'), (87363, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=94'), (93179, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=95'), (99372, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=96'), (105502, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=97'), (111449, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=98'), (117619, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=99'), (123472, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=100'), (129138, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=101'), (135136, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=102'), (140097, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=103'), (146244, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=104'), (152425, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=105')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/2-Friday, 27th September, 1901.txt
# Extracted Page Numbers: [(0, '39'), (3866, '40'), (9501, '41'), (15540, '42'), (21561, '43'), (27478, '44'), (33479, '45'), (39458, '46'), (45275, '47'), (51252, '48'), (57043, '49'), (63052, '50'), (68988, '51'), (75124, '52'), (81195, '53'), (87346, '54'), (93162, '55'), (99355, '56'), (105485, '57'), (111432, '58'), (117602, '59'), (123455, '60'), (129121, '61'), (135119, '62'), (140080, '63'), (146227, '64'), (152408, '65')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/2-Friday, 27th September, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/7-Wednesday, 9th October, 1901.txt
# Extracted date: Wednesday, 9th October, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=305'), (2111, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=306'), (8090, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=307'), (14144, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=308'), (20285, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=309'), (26455, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=310'), (32001, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=311'), (38250, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=312'), (44228, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=313'), (50388, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=314'), (56197, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=315'), (62333, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=316'), (67300, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=317'), (73440, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=318'), (78903, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=319'), (84741, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=320'), (90697, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=321'), (96355, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=322'), (102523, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=323'), (108343, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=324'), (114355, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=325'), (120516, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=326'), (126582, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=327'), (132770, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=328'), (138823, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=329'), (144848, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=330'), (151048, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=331'), (157211, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=332'), (163165, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=333'), (169131, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=334'), (175013, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=335'), (181260, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=336'), (187635, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=337'), (193778, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=338'), (200007, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=339'), (206197, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=340'), (212449, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=341'), (218820, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=342'), (224921, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=343'), (230872, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=344'), (236916, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=345'), (243116, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=346'), (249202, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=347')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/7-Wednesday, 9th October, 1901.txt
# Extracted Page Numbers: [(0, '265'), (2093, '266'), (8072, '267'), (14126, '268'), (20267, '269'), (26437, '270'), (31983, '271'), (38232, '272'), (44210, '273'), (50370, '274'), (56179, '275'), (62315, '276'), (67282, '277'), (73422, '278'), (78885, '279'), (84723, '280'), (90679, '281'), (96337, '282'), (102505, '283'), (108325, '284'), (114337, '285'), (120498, '286'), (126564, '287'), (132752, '288'), (138805, '289'), (144830, '290'), (151030, '291'), (157193, '292'), (163147, '293'), (169113, '294'), (174995, '295'), (181242, '296'), (187617, '297'), (193760, '298'), (199989, '299'), (206179, '300'), (212431, '301'), (218802, '302'), (224903, '303'), (230854, '304'), (236898, '305'), (243098, '306'), (249184, '307')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/7-Wednesday, 9th October, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/9-Tuesday, 20th August, 1901.txt
# Extracted date: Tuesday, 20th August, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=493'), (3536, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=494'), (9813, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=495'), (15956, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=496'), (22158, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=497'), (28472, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=498'), (34770, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=499'), (41074, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=500'), (47202, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=501'), (53356, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=502'), (58189, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=503'), (63916, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=504'), (69909, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=505'), (75863, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=506'), (81707, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=507'), (87586, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=508'), (93520, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=509'), (99214, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=510'), (105111, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=511'), (111012, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=512'), (116916, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=513'), (122820, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=514'), (128826, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=515'), (134726, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=516'), (140502, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=517'), (146515, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=518'), (152374, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=519'), (158239, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=520'), (163742, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=521'), (167958, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788246&seq=522')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/9-Tuesday, 20th August, 1901.txt
# Extracted Page Numbers: [(0, '463'), (3518, '464'), (9795, '465'), (15938, '466'), (22140, '467'), (28454, '468'), (34752, '469'), (41056, '470'), (47184, '471'), (53338, '472'), (58171, '473'), (63898, '474'), (69891, '475'), (75845, '476'), (81689, '477'), (87568, '478'), (93502, '479'), (99196, '480'), (105093, '481'), (110994, '482'), (116898, '483'), (122802, '484'), (128808, '485'), (134708, '486'), (140484, '487'), (146497, '488'), (152356, '489'), (158221, '490'), (163724, '491'), (167940, '492')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/9-Tuesday, 20th August, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/11-Friday, 19th July, 1901.txt
# Extracted date: Friday, 19th July, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=519'), (2455, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=520'), (7863, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=521'), (14030, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=522'), (19422, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=523'), (24513, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=524'), (30835, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=525'), (37139, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=526'), (43288, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=527'), (49316, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=528'), (55690, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=529'), (61881, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=530'), (68022, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=531'), (74119, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=532'), (80266, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=533'), (86595, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=534'), (92809, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=535'), (97814, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=536'), (103789, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=537'), (110006, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=538'), (116135, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=539'), (122121, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=540'), (128062, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=541'), (134516, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=542'), (140987, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=543'), (147074, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=544'), (153126, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=545'), (159348, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=546'), (165369, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=547'), (171575, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=548'), (177872, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=549'), (184195, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=550'), (190493, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=551'), (196856, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=552'), (203264, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=553'), (209544, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=554'), (215859, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=555'), (222187, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=556'), (228214, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=557'), (234518, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=558'), (240780, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=559'), (247142, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=560'), (253332, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=561'), (259701, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=562'), (265904, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=563'), (272066, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=564'), (278407, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=565'), (284836, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=566'), (291021, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=567'), (297375, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=568'), (303647, 'https://babel.hathitrust.org/cgi/pt?id=uc1.3210 ...
# Extracted Page Numbers: [(0, '491'), (2437, '492'), (7845, '493'), (14012, '494'), (19404, '495'), (24495, '496'), (30817, '497'), (37121, '498'), (43270, '499'), (49298, '500'), (55672, '501'), (61863, '502'), (68004, '503'), (74101, '504'), (80248, '505'), (86577, '506'), (92791, '507'), (97796, '508'), (103771, '509'), (109988, '510'), (116117, '511'), (122103, '512'), (128044, '513'), (134498, '514'), (140969, '515'), (147056, '516'), (153108, '517'), (159330, '518'), (165351, '519'), (171557, '520'), (177854, '521'), (184177, '522'), (190475, '523'), (196838, '524'), (203246, '525'), (209526, '526'), (215841, '527'), (222169, '528'), (228196, '529'), (234500, '530'), (240762, '531'), (247124, '532'), (253314, '533'), (259683, '534'), (265886, '535'), (272048, '536'), (278389, '537'), (284818, '538'), (291003, '539'), (297357, '540'), (303629, '541'), (309904, '542'), (316239, '543'), (322544, '544'), (328778, '545'), (335006, '546'), (341356, '547'), (347530, '548'), (353826, '549'), (360048, '550'), (366499, '551')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/11-Friday, 19th July, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/4-Friday, 6th September, 1901.txt
# Extracted date: Friday, 6th September, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=278'), (2559, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=279'), (8943, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=280'), (15205, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=281'), (21307, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=282'), (27499, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=283'), (33666, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=284'), (39848, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=285'), (45985, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=286'), (52327, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=287'), (58458, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=288'), (64585, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=289'), (70962, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=290'), (77120, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=291'), (82398, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=292'), (88316, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=293'), (94338, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=294'), (100535, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=295'), (106817, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=296'), (112949, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=297'), (119007, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=298'), (125029, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=299'), (131242, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=300'), (137365, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=301'), (143774, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=302'), (149878, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=303'), (156048, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=304'), (162046, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=305'), (168290, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=306'), (174668, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=307'), (181086, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=308'), (187471, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=309'), (193825, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=310'), (198465, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=311'), (204870, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=312'), (210739, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=313'), (216959, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=314'), (223243, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=315'), (228736, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=316'), (235013, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=317'), (240910, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=318'), (247278, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=319'), (252318, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=320'), (258565, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=321'), (264929, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=322'), (271145, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=323'), (277391, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=324'), (283586, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=325'), (289803, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=326'), (295968, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=327'), (302193, 'https://babel.hathitrust.org/cgi/pt?id=uc1.321 ...
# Extracted Page Numbers: [(0, '258'), (2541, '259'), (8925, '260'), (15187, '261'), (21289, '262'), (27481, '263'), (33648, '264'), (39830, '265'), (45967, '266'), (52309, '267'), (58440, '268'), (64567, '269'), (70944, '270'), (77102, '271'), (82380, '272'), (88298, '273'), (94320, '274'), (100517, '275'), (106799, '276'), (112931, '277'), (118989, '278'), (125011, '279'), (131224, '280'), (137347, '281'), (143756, '282'), (149860, '283'), (156030, '284'), (162028, '285'), (168272, '286'), (174650, '287'), (181068, '288'), (187453, '289'), (193807, '290'), (198447, '291'), (204852, '292'), (210721, '293'), (216941, '294'), (223225, '295'), (228718, '296'), (234995, '297'), (240892, '298'), (247260, '299'), (252300, '300'), (258547, '301'), (264911, '302'), (271127, '303'), (277373, '304'), (283568, '305'), (289785, '306'), (295950, '307'), (302175, '308'), (308133, '309'), (314014, '310'), (319971, '311'), (326004, '312'), (332226, '313'), (338569, '314'), (344539, '315'), (350824, '316'), (357089, '317'), (363397, '318'), (369632, '319'), (375974, '320'), (382233, '321'), (388471, '322'), (394643, '323'), (400979, '324'), (407190, '325'), (413232, '326'), (419125, '327'), (425319, '328'), (431205, '329'), (437425, '330')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/4-Friday, 6th September, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/8-Friday, 13th September, 1901.txt
# Extracted date: Friday, 13th September, 1901
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=520'), (3331, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=521'), (9600, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=522'), (15593, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=523'), (21714, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=524'), (28039, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=525'), (34324, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=526'), (39756, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=527'), (46024, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=528'), (52459, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=529'), (58701, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=530'), (64777, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=531'), (70922, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=532'), (77112, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=533'), (83291, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=534'), (89411, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=535'), (95542, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=536'), (100623, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=537'), (106156, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=538'), (110586, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=539'), (115437, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=540'), (120885, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=541'), (126893, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=542'), (133108, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=543'), (138959, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=544'), (144878, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=545'), (150703, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=546'), (156893, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=547'), (163086, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=548'), (168952, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=549'), (174858, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=550'), (180881, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=551'), (187009, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=552'), (192632, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=553'), (198925, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=554'), (204718, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=555'), (210809, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=556'), (216720, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=557'), (222372, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=558'), (228309, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=559'), (234519, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=560'), (240639, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=561'), (246600, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=562'), (252579, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=563'), (258399, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=564'), (264170, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=565'), (270083, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=566'), (275945, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=567'), (282059, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=568'), (288102, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788253&seq=569'), (293903, 'https://babel.hathitrust.org/cgi/pt?id=uc1.321 ...
# Extracted Page Numbers: [(0, '500'), (3313, '501'), (9582, '502'), (15575, '503'), (21696, '504'), (28021, '505'), (34306, '506'), (39738, '507'), (46006, '508'), (52441, '509'), (58683, '510'), (64759, '511'), (70904, '512'), (77094, '513'), (83273, '514'), (89393, '515'), (95524, '516'), (100605, '517'), (106138, '518'), (110568, '519'), (115419, '520'), (120867, '521'), (126875, '522'), (133090, '523'), (138941, '524'), (144860, '525'), (150685, '526'), (156875, '527'), (163068, '528'), (168934, '529'), (174840, '530'), (180863, '531'), (186991, '532'), (192614, '533'), (198907, '534'), (204700, '535'), (210791, '536'), (216702, '537'), (222354, '538'), (228291, '539'), (234501, '540'), (240621, '541'), (246582, '542'), (252561, '543'), (258381, '544'), (264152, '545'), (270065, '546'), (275927, '547'), (282041, '548'), (288084, '549'), (293885, '550'), (299434, '551'), (305226, '552'), (310744, '553'), (316218, '554'), (322352, '555'), (327371, '556'), (332028, '557')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/8-Friday, 13th September, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/4-Thursday, 4th July, 1901.txt
# Extracted date: Thursday, 4th July, 1901
# Extracted URL: [(17, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=90'), (430, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=91'), (6042, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=92'), (12269, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=93'), (18330, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=94'), (24471, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=95'), (30822, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=96'), (37053, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=97'), (43419, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=98'), (49816, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=99'), (56034, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=100'), (62107, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=101'), (68291, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=102'), (74658, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=103'), (81032, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=104'), (87206, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=105'), (93676, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=106'), (99874, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=107'), (106155, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=108'), (112452, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=109'), (118816, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=110'), (124952, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=111'), (131222, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=112'), (137645, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=113'), (143817, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=114'), (150079, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=115'), (156392, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=116'), (162628, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=117'), (168934, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=118'), (175074, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=119'), (181269, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=120'), (187431, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=121'), (193287, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=122'), (199322, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=123'), (205504, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=124'), (211632, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=125'), (217954, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=126'), (224202, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=127'), (230545, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=128'), (236915, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=129'), (243245, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788238&seq=130')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/4-Thursday, 4th July, 1901.txt
# Extracted Page Numbers: [(0, '62'), (413, '63'), (6025, '64'), (12252, '65'), (18313, '66'), (24454, '67'), (30805, '68'), (37036, '69'), (43402, '70'), (49799, '71'), (56017, '72'), (62090, '73'), (68274, '74'), (74641, '75'), (81015, '76'), (87189, '77'), (93659, '78'), (99857, '79'), (106138, '80'), (112435, '81'), (118799, '82'), (124935, '83'), (131205, '84'), (137628, '85'), (143800, '86'), (150062, '87'), (156375, '88'), (162611, '89'), (168917, '90'), (175057, '91'), (181252, '92'), (187414, '93'), (193270, '94'), (199305, '95'), (205487, '96'), (211615, '97'), (217937, '98'), (224185, '99'), (230527, '100'), (236897, '101'), (243227, '102')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/4-Thursday, 4th July, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/6-Tuesday, 8th October, 1501.txt
# Extracted date: Tuesday, 8th October, 1501
# Extracted URL: [(18, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=274'), (444, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=275'), (5916, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=276'), (12090, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=277'), (18328, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=278'), (24531, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=279'), (30475, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=280'), (36802, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=281'), (42978, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=282'), (49092, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=283'), (54014, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=284'), (59833, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=285'), (65431, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=286'), (71459, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=287'), (77675, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=288'), (83937, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=289'), (89949, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=290'), (94472, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=291'), (100336, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=292'), (106330, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=293'), (111196, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=294'), (117056, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=295'), (123021, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=296'), (128007, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=297'), (133063, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=298'), (138436, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=299'), (144582, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=300'), (150054, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=301'), (156031, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=302'), (161653, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=303'), (166858, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=304'), (172723, 'https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=305')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/6-Tuesday, 8th October, 1501.txt
# Extracted Page Numbers: [(0, '234'), (426, '235'), (5898, '236'), (12072, '237'), (18310, '238'), (24513, '239'), (30457, '240'), (36784, '241'), (42960, '242'), (49074, '243'), (53996, '244'), (59815, '245'), (65413, '246'), (71441, '247'), (77657, '248'), (83919, '249'), (89931, '250'), (94454, '251'), (100318, '252'), (106312, '253'), (111178, '254'), (117038, '255'), (123003, '256'), (127989, '257'), (133045, '258'), (138418, '259'), (144564, '260'), (150036, '261'), (156013, '262'), (161635, '263'), (166840, '264'), (172705, '265')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/6-Tuesday, 8th October, 1501.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/au/hofreps/txt/15-Friday, 26th July, 1901.txt
# Extracted date: Friday, 26th July, 1901
# ...
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Monday, 18th February, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 19th April, 1901.txt
# Extracted date: Friday, 19th April, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/apr/19')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 19th April, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 19th April, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th February, 1901.txt
# Extracted date: Friday, 15th February, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/feb/15')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th February, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th February, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Monday, 1st April, 1901.txt
# Extracted date: Monday, 1st April, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/apr/1')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Monday, 1st April, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Monday, 1st April, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th February, 1901.txt
# Extracted date: Thursday, 28th February, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/feb/28')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th February, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th February, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 16th May, 1901.txt
# Extracted date: Thursday, 16th May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/16')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 16th May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 16th May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday, 14th May, 1901.txt
# Extracted date: Tuesday, 14th May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/14')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday, 14th May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday, 14th May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 18th April, 1901.txt
# Extracted date: Thursday, 18th April, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/apr/18')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 18th April, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 18th April, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 23rd May, 1901.txt
# Extracted date: Thursday, 23rd May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/23')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 23rd May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 23rd May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th March, 1901.txt
# Extracted date: Friday, 15th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/15')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 15th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Saturday, 23rd March, 1901.txt
# Extracted date: Saturday, 23rd March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/23')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Saturday, 23rd March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Saturday, 23rd March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 7th June, 1901.txt
# Extracted date: Friday, 7th June, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/jun/7')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 7th June, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 7th June, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 26th June, 1901.txt
# Extracted date: Wednesday, 26th June, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/jun/26')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 26th June, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 26th June, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 6th March, 1901.txt
# Extracted date: Wednesday, 6th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/6')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 6th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 6th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 15th May, 1901.txt
# Extracted date: Wednesday, 15th May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/15')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 15th May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 15th May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th March, 1901.txt
# Extracted date: Thursday, 28th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/28')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 28th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th March, 1901.txt
# Extracted date: Wednesday, 20th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/20')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday 11th June, 1901.txt
# No date found, returning 'Unknown Date'
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/jun/11')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday 11th June, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Tuesday 11th June, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 8th August, 1901.txt
# Extracted date: Thursday, 8th August, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/aug/8')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 8th August, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 8th August, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th February, 1901.txt
# Extracted date: Wednesday, 27th February, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/feb/27')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th February, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th February, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th March, 1901.txt
# Extracted date: Wednesday, 27th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/27')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 27th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th February, 1901.txt
# Extracted date: Wednesday, 20th February, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/feb/20')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th February, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 20th February, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 6th June, 1901.txt
# Extracted date: Thursday, 6th June, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/jun/6')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 6th June, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Thursday, 6th June, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 13th March, 1901.txt
# Extracted date: Wednesday, 13th March, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/mar/13')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 13th March, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 13th March, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 24th May, 1901.txt
# Extracted date: Friday, 24th May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/24')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 24th May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Friday, 24th May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 23rd January, 1901.txt
# Extracted date: Wednesday, 23rd January, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/jan/23')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 23rd January, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 23rd January, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 22nd May, 1901.txt
# Extracted date: Wednesday, 22nd May, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/may/22')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 22nd May, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 22nd May, 1901.txt
# Extracting date from filename: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 24th April, 1901.txt
# Extracted date: Wednesday, 24th April, 1901
# Extracted URL: [(0, 'https://api.parliament.uk/historic-hansard/sittings/1901/apr/24')] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 24th April, 1901.txt
# Extracted Page Numbers: [] from document: /home/jamessmithies/Dropbox/Technical/projects/aiinfra/vector_sources/1901/uk/hofcoms/txt/Wednesday, 24th April, 1901.txt
# Finished processing corpus: 1901-uk
